# %%
import matplotlib.pyplot as plt
from matplotlib import cm

import seaborn as sns
import numpy as np
import pandas as pd

from sklearn.datasets import make_circles
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split


# %matplotlib inline

# %%
X, y = make_circles(n_samples = 100, shuffle = True, factor = .5, noise = .5)

# %%
logit = LogisticRegression()

logit.fit( X, y)

y_predict = logit.predict( X)
betas = np.c_[ logit.intercept_, logit.coef_]
betas = betas[0]
print( logit.score( X, y))
# Out:
# 0.5

# %%
x_train, x_test, y_train, y_test = train_test_split( X, y, random_state = 42)
logit = LogisticRegression()

logit.fit( x_train, y_train)

y_predict = logit.predict( x_train)
print( logit.score( X, y))

# %%
betas

# %%
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

ZZ = logit.predict(np.c_[xx.ravel(), yy.ravel()]) #mesh_transform
ZZ = ZZ.reshape(xx.shape)

## Decision Boundary
xx_line = np.arange( x_min, x_max, 0.01)
yy_line = (betas[0] + betas[1]*xx_line)/-betas[2]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in true_divide
#   if sys.path[0] == '':

# %%
type(X), X.shape

# %%
_ = plt.scatter( X[:,0], X[:, 1], c = y)

# %%
logit = LogisticRegression()

logit.fit( X, y)

y_predict = logit.predict( X)
betas = np.c_[ logit.intercept_, logit.coef_]
betas = betas[0]
print( logit.score( X, y))


## Create Mesh
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

ZZ = logit.predict(np.c_[xx.ravel(), yy.ravel()]) #mesh_transform
ZZ = ZZ.reshape(xx.shape)

## Decision Boundary Line
xx_line = np.arange( x_min, x_max, 0.01)
yy_line = (betas[0] + betas[1]*xx_line)/-betas[2]

f, (ax1, ax2) = plt.subplots(1,2, figsize=(24,12))
## plot original data
ax1.scatter( X[:,0], X[:, 1], c = y, cmap=cm.jet, s = 75)
ax1.set_xlabel(r'$x_{1}$')
ax1.set_ylabel(r'$x_{2}$')
ax1.set_xlim( x_min, x_max )
ax1.set_ylim(y_min, y_max)
## plot decision boundary
ax2.scatter( X[:,0], X[:, 1], c = y_predict,s = 75,cmap=cm.jet)
#ax2.plot(xx_line, yy_line)
ax2.contourf(xx, yy, ZZ, alpha=0.4, cmap=cm.jet)
ax2.set_xlabel(r'$x_{1}$')
ax2.set_ylabel(r'$x_{2}$')
ax2.set_xlim( x_min, x_max )
ax2.set_ylim(y_min, y_max)
# Out:
# 0.5
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in true_divide
# (-1.9980267284282716, 1.9980267284282716)

# %%
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
lsvc = LinearSVC()
lsvc.fit( X, y)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
lsvc.intercept_
# Out:
# array([ -6.78819723e-06])

# %%
lsvc.coef_
# Out:
# array([[ -1.03204846e-06,   1.29713812e-07]])

# %%
lsvc = LinearSVC()

lsvc.fit( X, y)

y_predict = logit.predict( X)
betas = np.c_[ logit.intercept_, logit.coef_]
betas = betas[0]
print( logit.score( X, y))


## Create Mesh
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

ZZ = logit.predict(np.c_[xx.ravel(), yy.ravel()]) #mesh_transform
ZZ = ZZ.reshape(xx.shape)

## Decision Boundary Line
xx_line = np.arange( x_min, x_max, 0.01)
yy_line = (betas[0] + betas[1]*xx_line)/-betas[2]

f, (ax1, ax2) = plt.subplots(1,2, figsize=(24,12))
## plot original data
ax1.scatter( X[:,0], X[:, 1], c = y, cmap=cm.jet, s = 75)
ax1.set_xlabel(r'$x_{1}$')
ax1.set_ylabel(r'$x_{2}$')
ax1.set_xlim( x_min, x_max )
ax1.set_ylim(y_min, y_max)
## plot decision boundary
ax2.scatter( X[:,0], X[:, 1], c = y_predict,s = 75,cmap=cm.jet)
#ax2.plot(xx_line, yy_line)
ax2.contourf(xx, yy, ZZ, alpha=0.4, cmap=cm.jet)
ax2.set_xlabel(r'$x_{1}$')
ax2.set_ylabel(r'$x_{2}$')
ax2.set_xlim( x_min, x_max )
ax2.set_ylim(y_min, y_max)
ax2.text()
# Out:
# 0.5
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in true_divide
# (-1.9980267284282716, 1.9980267284282716)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
dtc = DecisionTreeClassifier( max_depth = 2)
dtc.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
dtc.

# %%
from itertools import product
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

clf1 = LogisticRegression()
clf2 = LinearSVC()
clf3 = DecisionTreeClassifier(max_depth=4)
clf4 = KNeighborsClassifier(n_neighbors=7)


clf1.fit(X, y)
clf2.fit(X, y)
clf3.fit(X, y)
clf4.fit(X, y)

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

f, axarr = plt.subplots(2, 2, sharex='col', sharey='row', figsize=(10, 8))

for idx, clf, tt in zip(product([0, 1], [0, 1]),
                        [clf1, clf2, clf3, clf4],
                        ['Logistic Regression',
                         'Linear SVC',
                         'Decision Tree (d=4)',
                         'KNeighborsClassifier (k = 7)'
                        ]): 

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    
    y_predicted = clf.predict( X)
    score = str(clf.score(X,y))

    axarr[idx[0], idx[1]].contourf(xx, yy, Z, alpha=0.4, cmap=cm.jet)
    axarr[idx[0], idx[1]].scatter(X[:, 0], X[:, 1], c=y_predicted,  #c=y
                                  s=20, edgecolor='k', cmap=cm.jet)
    axarr[idx[0], idx[1]].set_title(tt + ' (' + score + ')')
    #axarr[idx[0], idx[1]].text( 0,2, score )

plt.show()

# %%
lsvc = LinearSVC()

lsvc.fit( X, y)

y_predict = logit.predict( X)
betas = np.c_[ logit.intercept_, logit.coef_]
betas = betas[0]
print( logit.score( X, y))


## Create Mesh
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

ZZ = logit.predict(np.c_[xx.ravel(), yy.ravel()]) #mesh_transform
ZZ = ZZ.reshape(xx.shape)

## Decision Boundary Line
xx_line = np.arange( x_min, x_max, 0.01)
yy_line = (betas[0] + betas[1]*xx_line)/-betas[2]

f, (ax1, ax2) = plt.subplots(1,2, figsize=(24,12))
## plot original data
ax1.scatter( X[:,0], X[:, 1], c = y, cmap=cm.jet, s = 75)
ax1.set_xlabel(r'$x_{1}$')
ax1.set_ylabel(r'$x_{2}$')
ax1.set_xlim( x_min, x_max )
ax1.set_ylim(y_min, y_max)
## plot decision boundary
ax2.scatter( X[:,0], X[:, 1], c = y_predict,s = 75,cmap=cm.jet)
#ax2.plot(xx_line, yy_line)
ax2.contourf(xx, yy, ZZ, alpha=0.4, cmap=cm.jet)
ax2.set_xlabel(r'$x_{1}$')
ax2.set_ylabel(r'$x_{2}$')
ax2.set_xlim( x_min, x_max )
ax2.set_ylim(y_min, y_max)

# %%
print( logit.score( X, y))
plt.scatter( X[:,0], X[:, 1], c = y_predict)
plt.show()

# %% [markdown]
# ### Classification failed because a linear method was applied on data that is non-linearly separable.

# %% [markdown]
# ## Let's transform the data from $ \{ (x,y) \in R^2\} \rightarrow (r, \theta) $

# %%
r = np.sqrt(X[:,0]**2 + X[:,1]**2)

theta = np.arctan2( X[:,1], X[:,0])

# %%
X_mid = np.c_[ r, theta]

x_min, x_max = X_mid[:, 0].min() - 1, X_mid[:, 0].max() + 1
y_min, y_max = X_mid[:, 1].min() - 1, X_mid[:, 1].max() + 1

xx_mid, yy_mid = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

#mesh_transform = poly.fit_transform( np.c_[xx.ravel(), yy.ravel()])
#mesh_transform.shape
ZZ_mid = logit.predict(np.c_[xx_mid.ravel(), yy_mid.ravel()]) #mesh_transform
ZZ_mid = ZZ_mid.reshape(xx_mid.shape)
#Z = Z.reshape(xx.shape)

ZZ_mid.shape
# Out:
# (82, 25)

# %%
#plt.contourf(xx_mid, yy_mid, ZZ_mid, alpha=0.4)
plt.scatter(r, theta, c = y)
plt.xlabel(r'$r$')
plt.ylabel(r'$\theta$')

# %% [markdown]
# ### Apply a rotation

# %% [markdown]
# ## $(r + \theta) $

# %%
r_p = r + theta

# %% [markdown]
# ## $(r - \theta) $

# %%
r_m = r - theta

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots( 1, 4, figsize =(48,12) )

ax1.scatter( X[:,0], X[:, 1], c = y, cmap=cm.jet, s = 75)
ax1.set_xlabel(r'$x_{1}$')
ax1.set_ylabel(r'$x_{2}$')
#ax1.set_xlim( x_min, x_max )
#ax1.set_ylim(y_min, y_max)

ax2.scatter(r, theta, c = y,cmap=cm.jet, s = 75)
ax2.set_xlabel(r'$r$')
ax2.set_ylabel(r'$\theta$')

ax3.scatter(r_p, r_m, c = y,cmap=cm.jet, s = 75)
ax3.set_xlabel(r'$(r + \theta)$')
ax3.set_ylabel(r'$(r - \theta)$')

print( logit.score( X_new, y))
#plt.rc('text', usetex=True)
ax4.contourf(xx_new, yy_new, ZZ, alpha=0.4,cmap=cm.jet, s = 75)
#ax4.plot(xx_line, yy_line)
ax4.scatter( X_new[:,0], X_new[:, 1], c = y_predict_new,cmap=cm.jet, s = 75)
ax4.set_xlabel(r'$(r + \theta)$')
ax4.set_ylabel(r'$(r - \theta)$')
#plt.show()
# Out:
# 1.0

# %%
plt.scatter(r_p, r_m, c = y)

# %%
#X_new = np.array( [r_p, r_m]).T

X_new = np.c_[ r_p, r_m]
X_new.shape
# Out:
# (100, 2)

# %%
logit.fit( X_new, y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_predict_new = logit.predict(X_new)

# %%
x_min, x_max = X_new[:, 0].min() - 1, X_new[:, 0].max() + 1
y_min, y_max = X_new[:, 1].min() - 1, X_new[:, 1].max() + 1

xx_new, yy_new = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

ZZ = logit.predict(np.c_[xx_new.ravel(), yy_new.ravel()]) #mesh_transform
ZZ = ZZ.reshape(xx_new.shape)
ZZ.shape
# Out:
# (87, 87)

# %%
betas = np.c_[ logit.intercept_, logit.coef_]

betas = betas[0]
betas
# Out:
# array([ 3.69802604, -2.61463103, -2.61045483])

# %%
xx_line = np.arange( x_min, x_max, 0.01)
yy_line = (betas[0] + betas[1]*xx_line)/-betas[2]
#plt.plot(xx_line, yy_line)

# %%
print( logit.score( X_new, y))
#plt.rc('text', usetex=True)
plt.contourf(xx_new, yy_new, ZZ, alpha=0.4)
plt.plot(xx_line, yy_line)
#plt.plot()
plt.scatter( X_new[:,0], X_new[:, 1], c = y_predict_new)
plt.xlabel(r'$(r + \theta)$')
plt.ylabel(r'$(r - \theta)$')
plt.show()
# Out:
# 1.0

# %% [markdown]
# ## Transform back to $ R^2 $

# %%
## PLOT Decision Boundary

rr_line = (xx_line + yy_line)/2
thetatheta_line = (xx_line - yy_line)/2

xx_rline = rr_line*np.cos( thetatheta_line)
yy_rline = rr_line*np.sin( thetatheta_line)

#Z = logit.predict(np.c_[xx.ravel(), yy.ravel()]) #mesh_transform
#Z = Z.reshape(xx.shape)

# %%
## Create final mesh with grid from last step by applying inverse transform
rr = (xx_new.ravel() + yy_new.ravel())/2
thetatheta = (xx_new.ravel() - yy_new.ravel())/2

xx_final = rr*np.cos( thetatheta)
yy_final = rr*np.sin( thetatheta)

# %%
## Create final mesh with grid from last step by applying inverse transform
rr = (xx_new + yy_new)/2
thetatheta = (xx_new - yy_new)/2

xx_final = rr*np.cos( thetatheta)
yy_final = rr*np.sin( thetatheta)

# %%
## TRY WITH xx_line, yy_line to create grid, FAIL

#xx_final, yy_final = np.meshgrid( xx_line, yy_line )

ZZ_final = logit.predict(np.c_[xx_final.ravel(), yy_final.ravel()]) #mesh_transform
ZZ_final = ZZ_final.reshape(xx_final.shape)

#ZZ_final = logit.predict(np.c_[xx_final, yy_final]) #mesh_transform
#ZZ_final = ZZ_final.reshape(xx_final.shape)

# %%
print( logit.score( X_new, y))
plt.plot( xx_line, yy_line, c = 'b')
plt.contourf(xx_final, yy_final, ZZ_final, alpha=0.4,cmap=cm.jet)
plt.scatter( X[:,0], X[:, 1], c = y_predict_new, cmap=cm.jet)

plt.show()
# Out:
# 1.0

# %%
print( logit.score( X_new, y))
plt.plot( xx_line, yy_line, c = 'b')
#plt.contourf(xx_final, yy_final, ZZ_final, alpha=0.4,cmap=cm.jet)
plt.scatter( X[:,0], X[:, 1], c = y_predict_new, cmap=cm.jet)

plt.show()
# Out:
# 1.0

# %% [markdown]
# ## Transform back into x and y

# %%
X[0:5, 0]

# %%
x = r*np.cos( theta)
x[0:5]

# %%
X[0:5,1]

# %%
y = r*np.sin( theta)
y[0:5]

# %%
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))
xx_line
yy_line

## xx = [r + theta]
## yy = [r - theta]
## r = (xx + yy)/2
## theta = (xx - yy)/2
#xx, yy 
#Z
rr_line = (xx_line + yy_line)/2

rr_line = (xx_line + yy_line)/2
thetatheta_line = (xx_line - yy_line)/2
xx_new[0,0:5], yy_new[0, 0:5]

#(xx_new[0,-5:] + yy_new[0, -5:])/2, rr[0,-5:]

#(xx_new[0,-5:] - yy_new[0, -5:])/2 == thetatheta[0,-5:]

#sum(sum( (xx_new - yy_new)/2 == thetatheta)), sum(sum( (xx_new + yy_new)/2 == rr))
#(xx_new[0,-5:] + yy_new[0, -5:])/2
#xx_new.shape, yy_new.shape

#rr.shape, thetatheta.shape
#thetatheta[0,0:5]
